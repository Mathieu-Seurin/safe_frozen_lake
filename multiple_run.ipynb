# %%
from lake import FrozenLakeEnvStop
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from copy import copy

from run_expe_tool import compare_algorithms, plot_result, run_multiple_expe, run_expe

from algo import TabQLearningControlerFeedback, TabQLearning, OptimalAgent

import pickle as pkl

# %matplotlib inline

# %%
# Common params
gamma = 0.99
expected_exploration_steps = 3000

game_algo_list = []

#######################
lr = 0.3
reward_when_falling = -0.1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No feed, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#############################
lr = 0.3
reward_when_falling = -1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No feed, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#########################################################################
lr = 0.5
reward_when_falling = -0.1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No feed, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#########################################################################

lr = 0.3
reward_when_falling = 0
margin = 0.1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
#################################

lr = 0.3
reward_when_falling = 0
margin = 0
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
#################################

lr = 0.1
reward_when_falling = 0
margin = 0.1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
###################################################################################

# %%
#result_dict = compare_algorithms(list_of_game_algo=game_algo_list, n_expe=500, n_episodes_train=400, n_tests=5, percentage_to_success=0.8)
#pkl.dump(result_dict, open("./first_comparison_result.pkl", 'wb'))

result_dict = pkl.load(open("./first_comparison_result.pkl", 'rb'))
plot_result(result_dict)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
# Common params
gamma = 0.99
expected_exploration_steps = 3000

game_algo_list = []

#######################
lr = 0.3
reward_when_falling = 0
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No rew, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#############################
lr = 0.7
reward_when_falling = -1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No rew, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#########################################################################

lr = 0.7
reward_when_falling = -1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearning(16, 4, gamma=gamma, lr=lr, expected_exploration_steps=expected_exploration_steps)

game_algo_list.append((game, algo, 'No feed, lr = {}, reward = {}'.format(lr, reward_when_falling)))
#########################################################################

lr = 0.3
reward_when_falling = 0
margin = 0.5
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
#################################

lr = 0.3
reward_when_falling = 0
margin = 0.7
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
#################################

lr = 0.1
reward_when_falling = 0
margin = 1
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=reward_when_falling, reset_when_falling=True)
algo = lambda : TabQLearningControlerFeedback(16, 4, gamma=gamma, lr=lr, 
                                            expected_exploration_steps=expected_exploration_steps, margin=margin)

game_algo_list.append((game, algo, 'Feedback, margin = {}, lr = {}, reward = {}'.format(margin, lr, reward_when_falling)))
###################################################################################

# %%
result_dict_2 = compare_algorithms(list_of_game_algo=game_algo_list, n_expe=500, n_episodes_train=400, n_tests=5, percentage_to_success=1)
pkl.dump(result_dict_2, open("./second_comparison_result.pkl", 'wb'))

# result_dict_2 = pkl.load(open("./second_comparison_result.pkl", 'rb'))
# plot_result(result_dict_2)
# Out:
# Finished No rew, lr = 0.3, reward = 0
# Finished No rew, lr = 0.7, reward = -1
# Finished No feed, lr = 0.7, reward = -1
# Finished Feedback, margin = 0.5, lr = 0.3, reward = 0
# Finished Feedback, margin = 0.7, lr = 0.3, reward = 0
# Finished Feedback, margin = 1, lr = 0.1, reward = 0

# %%
#result_dict['result_dict'].update(result_dict_2['result_dict'])
result_dict_2['result_dict'].keys()
del result_dict_2['result_dict']['No rew, lr = 0.3, reward = 0']
del result_dict['result_dict']['No feed, lr = 0.5, reward = -0.1']

# %%
plot_result(result_dict)

# %%
def plot_result(expe_dict):
    palette = sns.color_palette('colorblind')
    result_dict = expe_dict['result_dict']

    #  PLOT NUMBER OF FEEDBACK GIVEN BY ENV DURING test
    for n_item, (name, result) in enumerate(result_dict.items()):
        sns.tsplot(data=result['num_feedback_per_test_ep'][:, 300:], color=palette[n_item], legend=True)

    plt.legend(handles=plt.gca().get_lines(),
               labels=result_dict.keys())  # Handles is to avoid the blurry effect of snsplot
    plt.title("Num Feedback During Test")
    plt.show()

    #  PLOT % of goal reach during test
    for n_item, (name, result) in enumerate(result_dict.items()):
        sns.tsplot(data=result['percentage_goal_reach_array'][:, 300:], color=palette[n_item], legend=True)

    plt.legend(handles=plt.gca().get_lines(),
               labels=result_dict.keys())  # Handles is to avoid the blurry effect of snsplot
    plt.title("Percentage goal reach during test")
    plt.show()

    # Plot mean number of steps to reach goal
    for n_item, (name, result) in enumerate(result_dict.items()):
        sns.tsplot(data=result['steps_to_reach_goal'][:, 300:], color=palette[n_item], legend=True)

    # approx_min_steps_to_reach_goal = np.ones(result['steps_to_reach_goal'][:, 300:].shape[1]) * expe_dict[
    #     'minimum_number_of_steps']
    # sns.tsplot(data=approx_min_steps_to_reach_goal, color=palette[-1])
    legend = list(result_dict.keys())
    # legend.append("Estimate minimum number of steps to reach goal")

    h = plt.gca().get_lines()
    plt.legend(handles=h, labels=legend)

    plt.title("Number of steps to reach goal")
    plt.show()
    
    
plot_result(result_dict)

# %%
algo = lambda : OptimalAgent()
game = FrozenLakeEnvStop(is_slippery=True, reward_when_falling=0, reset_when_falling=True)

run_multiple_expe(algo, game, n_expe=500, n_episodes_train=200, n_tests=5, percentage_to_success=1, show=True)
# Out:
# Total steps to solve environment, mean 8758.538, std 1154.5571153286442
# Number of episodes mean 195.034, std 24.10279743100373
# Number of failure to solve env 485
# Number of episodes when not failing 66.8
# {'total_steps_array': array([ 9040.,  8223.,  8641.,  9541.,  8367.,  8364.,  8853.,  8979.,
#          9176.,  9166.,  9302.,  8270.,  8535.,  9395.,  8701.,  8965.,
#          9050.,  9019.,  8585.,  8983.,  9114.,  9734.,  8658.,  9315.,
#          8833.,  9073.,  8640.,  9069.,  8957.,  8779.,  9708.,  8313.,
#          9503.,  9193.,  8508.,  9886.,  8915.,  9017.,  8961.,   814.,
#          9638.,  8637.,  9252.,  8489.,  9149.,  8557.,  2056.,  9057.,
#          8541.,  9337.,  8723.,  8696.,  9017.,  8861.,  8932.,  8776.,
#          9206.,  8701.,  9179.,  8709.,  8807.,  8546.,  9534.,  8941.,
#          9408.,  8467.,  8726.,  9409.,  9312.,  8963.,  9264.,  8529.,
#          8886.,  8827.,  8497.,  9148.,  9068.,  9524.,  8931.,  8805.,
# ...

# %%
game = FrozenLakeEnvStop(is_slippery=True, reset_when_falling=0)
print(game.render())
game.P[9]
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# None
# {0: [(0.3333333333333333, 5, 0.0, True),
#   (0.3333333333333333, 8, 0.0, False),
#   (0.3333333333333333, 13, 0.0, False)],
#  1: [(0.3333333333333333, 8, 0.0, False),
#   (0.3333333333333333, 13, 0.0, False),
#   (0.3333333333333333, 10, 0.0, False)],
#  2: [(0.3333333333333333, 13, 0.0, False),
#   (0.3333333333333333, 10, 0.0, False),
#   (0.3333333333333333, 5, 0.0, True)],
#  3: [(0.3333333333333333, 10, 0.0, False),
#   (0.3333333333333333, 5, 0.0, True),
#   (0.3333333333333333, 8, 0.0, False)]}
